# %% [markdown]
# <a href="https://colab.research.google.com/github/emillycorreacosta-bit/ed-digital-9c/blob/main/quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## World Cup Quiz

# %%
import random

# Bank of 30 World Cup questions
questions_bank = [
    {
        "question": "Quem ganhou a primeira Copa do Mundo em 1930?",
        "options": {"a": "Brasil", "b": "Uruguai"},
        "correct_answer": "b"
    },
    {
        "question": "Qual país sediou a Copa do Mundo de 2014?",
        "options": {"a": "Brasil", "b": "Alemanha"},
        "correct_answer": "a"
    },
    {
        "question": "Qual jogador detém o recorde de mais gols marcados em Copas do Mundo?",
        "options": {"a": "Pelé", "b": "Miroslav Klose"},
        "correct_answer": "b"
    },
    {
        "question": "Quantas Copas do Mundo o Brasil já ganhou?",
        "options": {"a": "5", "b": "6"},
        "correct_answer": "a"
    },
    {
        "question": "Qual é o apelido da seleção alemã de futebol?",
        "options": {"a": "La Roja", "b": "Die Mannschaft"},
        "correct_answer": "b"
    },
    {
        "question": "Qual país sediou a Copa do Mundo de 2018?",
        "options": {"a": "Rússia", "b": "Qatar"},
        "correct_answer": "a"
    },
    {
        "question": "Qual seleção é conhecida como 'Laranja Mecânica'?",
        "options": {"a": "Holanda", "b": "Bélgica"},
        "correct_answer": "a"
    },
    {
        "question": "Quantas vezes a Itália ganhou a Copa do Mundo?",
        "options": {"a": "4", "b": "3"},
        "correct_answer": "a"
    },
    {
        "question": "Quem foi o artilheiro da Copa do Mundo de 2002?",
        "options": {"a": "Ronaldo Nazário", "b": "Miroslav Klose"},
        "correct_answer": "a"
    },
    {
        "question": "Qual país ganhou a Copa do Mundo de 2010?",
        "options": {"a": "Espanha", "b": "Alemanha"},
        "correct_answer": "a"
    },
    {
        "question": "Qual foi o único país africano a chegar às quartas de final da Copa do Mundo em 2010?",
        "options": {"a": "Gana", "b": "Camarões"},
        "correct_answer": "a"
    },
    {
        "question": "Quantos países participaram da primeira Copa do Mundo em 1930?",
        "options": {"a": "13", "b": "16"},
        "correct_answer": "a"
    },
    {
        "question": "Quem marcou o gol do título da Alemanha na Copa do Mundo de 2014?",
        "options": {"a": "Thomas Müller", "b": "Mario Götze"},
        "correct_answer": "b"
    },
    {
        "question": "Qual é o nome da bola oficial da Copa do Mundo de 2022?",
        "options": {"a": "Jabulani", "b": "Al Rihla"},
        "correct_answer": "b"
    },
    {
        "question": "Qual o nome do técnico que levou a seleção brasileira ao Pentacampeonato em 2002?",
        "options": {"a": "Tite", "b": "Felipão"},
        "correct_answer": "b"
    },
    {
        "question": "Qual jogador argentino é famoso pela 'Mão de Deus' na Copa de 1986?",
        "options": {"a": "Lionel Messi", "b": "Diego Maradona"},
        "correct_answer": "b"
    },
    {
        "question": "Qual país sediou a Copa do Mundo de 2006?",
        "options": {"a": "Itália", "b": "Alemanha"},
        "correct_answer": "b"
    },
    {
        "question": "Quem foi o artilheiro da Copa do Mundo de 1994?",
        "options": {"a": "Romário", "b": "Oleg Salenko"},
        "correct_answer": "a"
    },
    {
        "question": "Qual país venceu a Copa do Mundo Feminina de 2019?",
        "options": {"a": "Estados Unidos", "b": "Holanda"},
        "correct_answer": "a"
    },
    {
        "question": "Qual é a seleção com mais participações em Copas do Mundo?",
        "options": {"a": "Brasil", "b": "Alemanha"},
        "correct_answer": "a"
    },
    {
        "question": "Qual foi o mascote da Copa do Mundo de 2014 no Brasil?",
        "options": {"a": "Fuleco", "b": "Zakumi"},
        "correct_answer": "a"
    },
    {
        "question": "Qual o nome do estádio onde a final da Copa de 1950 (Maracanaço) foi disputada?",
        "options": {"a": "Mineirão", "b": "Maracanã"},
        "correct_answer": "b"
    },
    {
        "question": "Em que ano a Copa do Mundo foi sediada pela Coreia do Sul e Japão?",
        "options": {"a": "2002", "b": "1998"},
        "correct_answer": "a"
    },
    {
        "question": "Qual país ganhou a Copa do Mundo em 1998?",
        "options": {"a": "Brasil", "b": "França"},
        "correct_answer": "b"
    },
    {
        "question": "Qual foi o resultado da final da Copa do Mundo de 2014 entre Alemanha e Argentina?",
        "options": {"a": "1 a 0 para a Alemanha", "b": "2 a 1 para a Alemanha"},
        "correct_answer": "a"
    },
    {
        "question": "Qual é o país que mais vezes foi vice-campeão da Copa do Mundo?",
        "options": {"a": "Alemanha", "b": "Argentina"},
        "correct_answer": "a"
    },
    {
        "question": "Quem foi o capitão da seleção brasileira na Copa do Mundo de 1970?",
        "options": {"a": "Pelé", "b": "Carlos Alberto Torres"},
        "correct_answer": "b"
    },
    {
        "question": "Qual foi o placar mais elástico em uma Copa do Mundo?",
        "options": {"a": "Hungria 10 x 1 El Salvador (1982)", "b": "Alemanha 7 x 1 Brasil (2014)"},
        "correct_answer": "a"
    },
    {
        "question": "Qual seleção é a atual campeã da Copa do Mundo (2022)?",
        "options": {"a": "França", "b": "Argentina"},
        "correct_answer": "b"
    },
    {
        "question": "Qual país sediará a Copa do Mundo de 2026?",
        "options": {"a": "Estados Unidos, Canadá e México", "b": "Marrocos"},
        "correct_answer": "a"
    }
]

# Randomly select 10 questions from the bank
quiz_questions = random.sample(questions_bank, 10)

print("Bem-vindo ao Quiz da Copa do Mundo!")
print("Você precisa acertar 10 perguntas consecutivas para ganhar o jogo.")
print("Se errar, o jogo termina.")

score = 0
for i, q in enumerate(quiz_questions):
    print(f"\n--- Pergunta {i + 1} ---")
    print(q['question'])
    print(f"a) {q['options']['a']}")
    print(f"b) {q['options']['b']}")

    while True:
        user_answer = input("Sua resposta (a ou b): ").lower()
        if user_answer in ['a', 'b']:
            break
        else:
            print("Resposta inválida. Por favor, digite 'a' ou 'b'.")

    if user_answer == q['correct_answer']:
        print("Correto!")
        score += 1
    else:
        print(f"Errado! A resposta correta era '{q['correct_answer']}'.")
        print("GAME OVER! Você perdeu o jogo.")
        break # End the game if an answer is incorrect

if score == 10:
    print("\nPARABÉNS! Você acertou todas as 10 perguntas e ganhou o jogo!")
else:
    print(f"Você acertou {score} de 10 perguntas antes de perder.")
# Out:
# Bem-vindo ao Quiz da Copa do Mundo!
# Você precisa acertar 10 perguntas consecutivas para ganhar o jogo.
# Se errar, o jogo termina.
#
# --- Pergunta 1 ---
# Qual jogador detém o recorde de mais gols marcados em Copas do Mundo?
# a) Pelé
# b) Miroslav Klose
# Sua resposta (a ou b): b
# Correto!
#
# --- Pergunta 2 ---
# Em que ano a Copa do Mundo foi sediada pela Coreia do Sul e Japão?
# a) 2002
# b) 1998
# Sua resposta (a ou b): a
# Correto!
#
# --- Pergunta 3 ---
# Qual foi o mascote da Copa do Mundo de 2014 no Brasil?
# a) Fuleco
# b) Zakumi
# Sua resposta (a ou b): a
# Correto!
#
# --- Pergunta 4 ---
# Qual país sediou a Copa do Mundo de 2006?
# a) Itália
# b) Alemanha
# Sua resposta (a ou b): b
# Correto!
#
# --- Pergunta 5 ---
# Qual país venceu a Copa do Mundo Feminina de 2019?
# a) Estados Unidos
# b) Holanda
# Sua resposta (a ou b): a
# Correto!
#
# --- Pergunta 6 ---
# Qual país ganhou a Copa do Mundo em 1998?
# a) Brasil
# b) França
# Sua resposta (a ou b): b
# Correto!
#
# ...

# %%
preciso criar um quiz sobre a copa do mundo, com 10 perguntas, onde o usuario tera que acertar todas as perguntas para a ganhar o jogo. Elabore 30 perguntas para o banco de perguntas, das quais 10 serão sorteadas para a rodada. As perguntas deverão oferecer duas opçoẽs de respostas, sendo que só uma é correta. O usuário devera responder a ou b. caso acerte passe para a proxima, se errar perde o jogo. caso acerte todas ganha o jogo
